# %% [markdown]
# ## EXERCISES

# %% [markdown]
# #### Exercise 1

# %% [markdown]
# Given the code below
#
#     text = 'Business Analytics'
#
# What will the following expressions produce?
#
#     text[4]
#     text[2:4]
#     text[:4]
#     text[4:]
#     text[-2]
#     text[-4:-2]
#     text[-2:]
#     text[:-2]

# %%
text = 'Business Analytics'
text[4]
#n
text[2:4]
#si
text[:4]
#busi
text[4:]
#ness Analytics
text[-2]
#cs
text[-4:-2]
#ti
text[-2:]
#cs
text[:-2]
#Business Analyti
# Out:
# 'Business Analyti'

# %% [markdown]
# #### Exercise 2

# %% [markdown]
# Given the code below:
#
#     phrase = 'One Ring to rule them all'
#
# What string slicing expression gives out the following words:
#
#     'One '
#     'Ring'
#     'all'
#     'them'
#     'One Ring to rule them all'

# %%
phrase = 'One Ring to rule them all'

# 'One '
substring1 = phrase[:4]
print(substring1)

# 'Ring'
substring2 = phrase[4:8]
print(substring2)

# 'all'
substring3 = phrase[-3:]
print(substring3)

# 'them'
substring4 = phrase[17:21]
print(substring4)

# 'One Ring to rule them all'
substring5 = phrase[:]
print(substring5)
# Out:
# One
# Ring
# all
# them
# One Ring to rule them all

# %% [markdown]
# ## CHALLENGE

# %% [markdown]
# Write a program which repeatedly reads a **full name**, then does the following:
# - strips the name of any trailing spaces
# - capitalizes the first letter
# - puts the rest into smaller letters

# %%
full_name = input("Enter a full name: ")

formatted_name = full_name.strip().capitalize()

print("Formatted name:", formatted_name)
# Out:
# Enter a full name: efie kathleen
# Formatted name: Efie kathleen
