# %% [markdown]
# EXERCISE 1

# %%
#Print('Hello world!')
# the p in print is capital letter.
print('Hello world!')
# Out:
# Hello world!
# 'Hello World!'

# %%
#print'Hello world!')
# a parenthesis is missing.
print('Hello world!')
# Out:
# Hello world!

# %%
#print('Hello world!)
# a closing qoutation mark is missing.
print('Hello world!')
# Out:
# Hello world!

# %%
#print('Hello world!'')
# there is an extra closing qoutation mark.
print('Hello world!')
# Out:
# Hello world!

# %% [markdown]
# EXERCISE 2

# %%
x = 43
x = x + 1
print(x)

# 44
# Out:
# 44

# %% [markdown]
# EXERCISE 3

# %%
#x = 43
#x = X + 1
#print(x)

# the X has no value.

x = 43
x = x + 1
print(x)
# Out:
# 44
