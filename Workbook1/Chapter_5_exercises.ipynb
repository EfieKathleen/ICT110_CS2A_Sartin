# %% [markdown]
# #### Exercise 1

# %% [markdown]
# Investigate on the difference between `is` and `==` given the following variables.
# ```python
# a = 2
# b = 2.0
# c = a
# ```

# %%
a = 2
b = 2.0
c = a

print(a is b)
# this will be False because the data types that inside of a and b variable is not the same even though a and b varibale hold the same value. a data types is integer and b is float.

print(a == b)
# this will be True because the value between the variable a and b are the same , regardless of their data types.

print(b is c)
#this will be False because the data types that inside of a and b variable is not the same even though c and b varibale hold the same value. The c variable is assigned of what the value of variable a which is an integer and the data types of b is float.

print(b == c)
# this will be True because the value between the variable c and b are the same , regardless of their data types. The value of variable c is what the value of variable a because variable c is assigned the value of variable a.
# Out:
# False
# True
# False
# True

# %% [markdown]
# #### Challenge 1

# %% [markdown]
# Write a program which repeatedly reads numbers until the user enters "done". Once "done" is entered, print out the total, count, and average of the numbers. If the user enters anything other than a number, detect their mistake using try and except and print an error message and skip to the next number.
#
#     Enter a number: 4
#     Enter a number: 5
#     Enter a number: bad data
#     Invalid input
#     Enter a number: 7
#     Enter a number: done
#     16 3 5.333333333333333
#
# [PEW] E5.1

# %%
total = 0
count = 0
while True:
  try:
      num = input("Enter a number: ")
      if num.lower() == "done":
        break
      num = float(num)
      total += num
      count += 1
  except ValueError:
        print("Invalid input")


if count > 0:
    average = total / count
    print(f"Total: {total}")
    print(f"Count: {count}")
    print(f"Average: {average}")
else:
    print("No numbers were entered")
# Out:
# Enter a number: 4
# Enter a number: 5
# Enter a number: no
# Invalid input
# Enter a number: 7
# Enter a number: done
# Total: 16.0
# Count: 3
# Average: 5.333333333333333

# %% [markdown]
# #### Challenge 2

# %% [markdown]
# Write another program that prompts for a list of numbers as above and at the end prints out both the maximum and minimum of the numbers instead of the average.
#
# [PEW] E5.2

# %%
numbers = []
while True:
     try:
       num = input("Enter a number: ")
       if num == "done":
         break
       input_user = float(num)
       numbers.append(input_user)
     except ValueError:
        print("Invalid input")


if numbers:
  maximum = max(numbers)
  minimum = min(numbers)
  print('maximum: ', maximum)
  print('minimum: ', minimum)
else:
  print("No numbers were entered")
# Out:
# Enter a number: 4
# Enter a number: 5
# Enter a number: 7
# Enter a number: done
# maximum:  7.0
# minimum:  4.0
